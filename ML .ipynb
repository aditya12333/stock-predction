# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/adity/Downloads/data_stocks (1).csv')
data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
#    NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  \
# 0     44.40    39.88     82.03      7.36     50.22     63.86   122.000
# 1     44.11    39.88     82.03      7.38     50.22     63.74   121.770
# 2     44.09    39.98     82.02      7.36     50.12     63.75   121.700
# 3     44.25    39.99     82.02      7.35     50.16     63.88   121.700
# 4     44.11    39.96     82.03      7.36     50.20     63.91   121.695
#
#    NYSE.ZTS
# 0    53.350
# 1    53.350
# 2    53.365
# 3    53.380
# 4    53.240
#
# [5 rows x 502 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
data.shape
# Out:
# (41266, 502)

# %%
data.describe()
# Out:
#                DATE         SP500    NASDAQ.AAL   NASDAQ.AAPL  NASDAQ.ADBE  \
# count  4.126600e+04  41266.000000  41266.000000  41266.000000  41266.00000
# mean   1.497749e+09   2421.537882     47.708346    150.453566    141.31793
# std    3.822211e+06     39.557135      3.259377      6.236826      6.91674
# min    1.491226e+09   2329.139900     40.830000    140.160000    128.24000
# 25%    1.494432e+09   2390.860100     44.945400    144.640000    135.19500
# 50%    1.497638e+09   2430.149900     48.360000    149.945000    142.26000
# 75%    1.501090e+09   2448.820100     50.180000    155.065000    147.10000
# max    1.504210e+09   2490.649900     54.475000    164.510000    155.33000
#
#          NASDAQ.ADI    NASDAQ.ADP   NASDAQ.ADSK   NASDAQ.AKAM   NASDAQ.ALXN  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean      79.446873    103.480398    102.998608     50.894352    122.981163
# std        2.000283      4.424244      9.389788      4.833931     11.252010
# min       74.800000     95.870000     83.000000     44.650000     96.250000
# 25%       78.030000    101.300000     94.820000     47.440000    116.950000
# 50%       79.410000    102.440000    106.820000     49.509900    123.620000
# 75%       80.580000    104.660000    110.490000     52.230000    132.218800
# max       90.440000    121.770000    119.270000     62.560000    142.875000
#
#        ...      NYSE.WYN      NYSE.XEC      NYSE.XEL       NYSE.XL  \
# count  ...  41266.000000  41266.000000  41266.000000  41266.000000
# mean   ...     97.942211    104.740666     46.664402     43.043984
# std    ...      5.411795     10.606694      1.508444      1.714533
# min    ...     83.410000     89.510000     44.090000     39.120000
# 25%    ...     95.960000     95.010000     45.155000     41.955000
# 50%    ...     99.250000     99.660000     46.810000     43.200000
# 75%    ...    102.080000    117.034700     47.730000     44.370000
# max    ...    106.375000    123.870000     49.660000     47.210000
#
#            NYSE.XOM      NYSE.XRX      NYSE.XYL      NYSE.YUM      NYSE.ZBH  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean      80.784595     19.300718     54.541988     71.757891    121.423515
# std        1.840989     11.686532      3.526321      4.038272      5.607070
# min       76.060000      6.660000     48.820000     63.180000    110.120000
# 25%       80.220000      7.045000     51.630000     69.110000    117.580000
# 50%       81.150000     27.890000     53.850000     73.470000    120.650000
# 75%       82.062050     30.470000     57.140000     74.750000    126.000000
# max       83.630000     32.930000     62.130000     77.120000    133.450000
#
#            NYSE.ZTS
# count  41266.000000
# mean      60.183874
# std        3.346887
# min       52.300000
# 25%       59.620000
# 50%       61.585600
# 75%       62.540000
# max       63.840000
#
# [8 rows x 502 columns]

# %%
data.columns[data.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
corr = data.corr()

# %%
corr_dt = pd.DataFrame(data = corr, columns = corr.index, index = corr.index)
corr_dt.head()
# Out:
#                  DATE     SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# DATE         1.000000  0.885359    0.519808     0.651512     0.953397
# SP500        0.885359  1.000000    0.712007     0.553332     0.909061
# NASDAQ.AAL   0.519808  0.712007    1.000000     0.082065     0.542213
# NASDAQ.AAPL  0.651512  0.553332    0.082065     1.000000     0.714578
# NASDAQ.ADBE  0.953397  0.909061    0.542213     0.714578     1.000000
#
#              NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  \
# DATE           0.102760    0.568293     0.793204    -0.757786     0.605316
# SP500          0.219471    0.562785     0.834350    -0.690018     0.450572
# NASDAQ.AAL     0.209446    0.245801     0.610881    -0.441142     0.009581
# NASDAQ.AAPL    0.264269    0.265641     0.645233    -0.712522     0.326712
# NASDAQ.ADBE    0.259282    0.476496     0.872353    -0.759604     0.488717
#
#              ...  NYSE.WYN  NYSE.XEC  NYSE.XEL   NYSE.XL  NYSE.XOM  NYSE.XRX  \
# DATE         ...  0.669316 -0.829196  0.833376  0.709542 -0.788489  0.895679
# SP500        ...  0.847975 -0.848511  0.741641  0.820043 -0.517492  0.805525
# NASDAQ.AAL   ...  0.798624 -0.744085  0.284370  0.810955 -0.070950  0.522341
# NASDAQ.AAPL  ...  0.306664 -0.250959  0.738655  0.266994 -0.671488  0.341687
# NASDAQ.ADBE  ...  0.718851 -0.792876  0.850709  0.722161 -0.758967  0.806615
#
#              NYSE.XYL  NYSE.YUM  NYSE.ZBH  NYSE.ZTS
# DATE         0.965059  0.923129 -0.130091  0.719325
# SP500        0.849908  0.915986  0.143752  0.813459
# NASDAQ.AAL   0.395730  0.642336  0.588241  0.753567
# NASDAQ.AAPL  0.693062  0.627531 -0.580055  0.442600
# NASDAQ.ADBE  0.911106  0.939185 -0.067235  0.776052
#
# [5 rows x 502 columns]

# %%
corr_dt[corr_dt['NASDAQ.AAL'].values>0.80][:5]
# Out:
#                  DATE     SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  \
# NASDAQ.AAL   0.519808  0.712007    1.000000     0.082065     0.542213
# NASDAQ.AMZN  0.623954  0.834878    0.803319     0.370111     0.730719
# NASDAQ.EXPE  0.779218  0.892177    0.812206     0.379622     0.818384
# NASDAQ.HAS   0.196355  0.473669    0.832713    -0.274890     0.251696
# NYSE.CMI     0.493660  0.720325    0.810391     0.088336     0.528227
#
#              NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  \
# NASDAQ.AAL     0.209446    0.245801     0.610881    -0.441142     0.009581
# NASDAQ.AMZN    0.386619    0.252712     0.828757    -0.648854     0.059345
# NASDAQ.EXPE    0.218189    0.369697     0.834440    -0.707045     0.296553
# NASDAQ.HAS     0.252954   -0.030201     0.394658    -0.206013    -0.208923
# NYSE.CMI       0.206259    0.179664     0.577301    -0.458993     0.140823
#
#              ...  NYSE.WYN  NYSE.XEC  NYSE.XEL   NYSE.XL  NYSE.XOM  NYSE.XRX  \
# NASDAQ.AAL   ...  0.798624 -0.744085  0.284370  0.810955 -0.070950  0.522341
# NASDAQ.AMZN  ...  0.879967 -0.733852  0.530139  0.804398 -0.203979  0.533584
# NASDAQ.EXPE  ...  0.931258 -0.825230  0.591514  0.859042 -0.368192  0.712184
# NASDAQ.HAS   ...  0.698866 -0.609800  0.035341  0.625126  0.264187  0.306630
# NYSE.CMI     ...  0.803020 -0.677137  0.226787  0.767652 -0.003402  0.521924
#
#              NYSE.XYL  NYSE.YUM  NYSE.ZBH  NYSE.ZTS
# NASDAQ.AAL   0.395730  0.642336  0.588241  0.753567
# NASDAQ.AMZN  0.503878  0.793529  0.419472  0.872246
# NASDAQ.EXPE  0.658203  0.883902  0.347660  0.913009
# NASDAQ.HAS   0.055201  0.406760  0.839854  0.651842
# NYSE.CMI     0.370814  0.616157  0.581472  0.753369
#
# [5 rows x 502 columns]

# %% [markdown]
# ## exercise 2

# %%
from numpy import vstack, array
from numpy.random import rand
import numpy as np
from scipy.cluster.vq import kmeans,vq
import pandas as pd
from math import sqrt
from sklearn.cluster import KMeans

# %%
returns  =  data.pct_change().mean()*252
returns = pd.DataFrame(returns)
returns.columns = ["Returns"]
returns.Volatility = data.pct_change().std()*sqrt(252)

dta = np.asarray([np.asarray(returns.Returns), np.asarray(returns.Volatility)]).T
# Out:
# C:\Users\adity\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   after removing the cwd from sys.path.

# %%
X = dta
distortions =[]
for k in range(2,20):
    k_means = KMeans(n_clusters = k)
    k_means.fit(X)
    distortions.append(k_means.inertia_)

fig = plt.figure(figsize=(15,5))
plt.plot(range(2,20),distortions)
plt.grid(True)
plt.title('Elbow-Curve')
plt.show()

# %%
from pylab import plot, show
# Computing kmeans with K =5 (5 clusters)
centroids,_= kmeans(dta, 5)
# Assign each sample to a cluster
idx,_ = vq(dta, centroids)

# some plotting using numpy's logical indexing
plot(dta[idx==0,0],dta[idx==0,1],'ob',
     dta[idx==1,0],dta[idx==1,1],'oy',
     dta[idx==2,0],dta[idx==2,1],'or',
     dta[idx==3,0],dta[idx==3,1],'og',
     dta[idx==4,0],dta[idx==4,1],'om')
plot(centroids[:,0],centroids[:,1],'sg',markersize=8)
show()

# %%
print(returns.idxmax())
# Out:
# Returns    NYSE.XRX
# dtype: object

# %%
data.drop(['NYSE.XRX','DATE','SP500'],inplace=True,axis=1)

returns = data.pct_change().mean()*252
returns = pd.DataFrame(returns)
returns.columns = ['Returns']
returns.Volatility = data.pct_change().std()*sqrt(252)
dta = np.asarray([np.asarray(returns.Returns), np.asarray(returns.Volatility)]).T
centroids,_= kmeans(dta, 5)
idx,_ = vq(dta, centroids)

plot(dta[idx==0,0],dta[idx==0,1],'ob',
     dta[idx==1,0],dta[idx==1,1],'oy',
     dta[idx==2,0],dta[idx==2,1],'or',
     dta[idx==3,0],dta[idx==3,1],'og',
     dta[idx==4,0],dta[idx==4,1],'om')
plot(centroids[:,0],centroids[:,1],'sg',markersize=8)
show()
# Out:
# C:\Users\adity\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
details = [(name,cluster) for name, cluster in zip(returns.index,idx)]
details[:5]
# Out:
# [('NASDAQ.AAL', 2),
#  ('NASDAQ.AAPL', 4),
#  ('NASDAQ.ADBE', 4),
#  ('NASDAQ.ADI', 3),
#  ('NASDAQ.ADP', 3)]

# %%
df = pd.DataFrame(details, columns=['Stock_Name','Cluster_No'])
df.Cluster_No.value_counts()
# Out:
# 4    153
# 3    120
# 1    102
# 2     94
# 0     30
# Name: Cluster_No, dtype: int64

# %%
import seaborn as sns
ind = df.Cluster_No.value_counts()
plt.figure(figsize=(12,4))
sns.barplot(x=ind.index, y=ind.values, alpha=0.6)
plt.ylabel('Number of Occurences',fontsize=12)
plt.xlabel('Cluster Number',fontsize=12)
plt.title('Barplot - Indicator',fontsize =16)
plt.show()

# %% [markdown]
# ## Exercise 3

# %%
data = pd.read_csv('C:/Users/adity/Downloads/data_stocks (1).csv')
data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
#    NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  \
# 0     44.40    39.88     82.03      7.36     50.22     63.86   122.000
# 1     44.11    39.88     82.03      7.38     50.22     63.74   121.770
# 2     44.09    39.98     82.02      7.36     50.12     63.75   121.700
# 3     44.25    39.99     82.02      7.35     50.16     63.88   121.700
# 4     44.11    39.96     82.03      7.36     50.20     63.91   121.695
#
#    NYSE.ZTS
# 0    53.350
# 1    53.350
# 2    53.365
# 3    53.380
# 4    53.240
#
# [5 rows x 502 columns]

# %%
dt = data.copy()
dt.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
#    NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  \
# 0     44.40    39.88     82.03      7.36     50.22     63.86   122.000
# 1     44.11    39.88     82.03      7.38     50.22     63.74   121.770
# 2     44.09    39.98     82.02      7.36     50.12     63.75   121.700
# 3     44.25    39.99     82.02      7.35     50.16     63.88   121.700
# 4     44.11    39.96     82.03      7.36     50.20     63.91   121.695
#
#    NYSE.ZTS
# 0    53.350
# 1    53.350
# 2    53.365
# 3    53.380
# 4    53.240
#
# [5 rows x 502 columns]

# %%
dt.drop(['DATE','SP500'],inplace=True,axis=1)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
X = dt.values

sc = StandardScaler()
X_scaled = sc.fit_transform(X)

pca = PCA(n_components=150)
pca.fit(X_scaled)

# the amount of variance that each PCA explains
var = pca.explained_variance_ratio_

# cumulative varince explains
var1 = np.cumsum(np.round(var, decimals=4)*100)
print(var1)
# Out:
# [47.03 64.26 76.28 81.13 84.93 87.74 89.74 91.05 92.1  92.85 93.53 94.11
#  94.57 95.02 95.43 95.78 96.11 96.37 96.6  96.82 97.01 97.17 97.32 97.45
#  97.58 97.7  97.81 97.91 98.   98.08 98.16 98.24 98.31 98.38 98.44 98.5
#  98.56 98.61 98.66 98.71 98.75 98.79 98.83 98.87 98.91 98.94 98.97 99.
#  99.03 99.06 99.09 99.12 99.15 99.17 99.19 99.21 99.23 99.25 99.27 99.29
#  99.31 99.33 99.35 99.37 99.39 99.41 99.43 99.45 99.46 99.47 99.48 99.49
#  99.5  99.51 99.52 99.53 99.54 99.55 99.56 99.57 99.58 99.59 99.6  99.61
#  99.62 99.63 99.64 99.65 99.66 99.67 99.68 99.69 99.7  99.71 99.72 99.73
#  99.74 99.75 99.76 99.77 99.78 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79 99.79
#  99.79 99.79 99.79 99.79 99.79 99.79]

# %%
plt.plot(var1)

# %%
pca = PCA(n_components =30)
X1 = pca.fit_transform(X_scaled)
print(X1)
# Out:
# [[ 25.55018064  10.00580482  -9.38207446 ...  -1.75017026   0.63799408
#     0.37444217]
#  [ 25.64880185   9.89282687  -9.8023104  ...  -1.51796773   0.47603426
#     0.55947606]
#  [ 25.56345929   9.82533675  -9.67570287 ...  -1.5455433    0.49110472
#     0.64203318]
#  ...
#  [-22.76894921  13.32753802   6.56220278 ...  -0.94437882  -0.07674832
#     0.57531063]
#  [-22.61319638  13.41831515   6.6755356  ...  -0.93018904  -0.0430579
#     0.58965901]
#  [-22.72127837  13.36292841   6.60406294 ...  -0.92988049  -0.05430596
#     0.55505574]]

# %%
print('Number of PCA :',len(pca.components_))
print(abs(pca.components_))
# Out:
# Number of PCA : 30
# [[0.03925756 0.04106421 0.0629084  ... 0.06247664 0.00253829 0.05169773]
#  [0.06428354 0.033861   0.00186129 ... 0.02040637 0.08122924 0.05950068]
#  [0.03985758 0.06416494 0.01207933 ... 0.02101011 0.06637293 0.02356977]
#  ...
#  [0.00731378 0.0490318  0.00751537 ... 0.03153241 0.05664978 0.01246238]
#  [0.0132518  0.00107252 0.00953619 ... 0.02752468 0.00892497 0.01389085]
#  [0.01058427 0.08406379 0.00524424 ... 0.01108133 0.04903182 0.03221396]]

# %%
comp = pd.DataFrame(pca.components_, columns = dt.columns)
comp.head()
# Out:
#    NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  NASDAQ.ADP  NASDAQ.ADSK  \
# 0   -0.039258    -0.041064    -0.062908   -0.009788   -0.035866    -0.054668
# 1   -0.064284     0.033861     0.001861   -0.032453    0.043511    -0.029519
# 2   -0.039858     0.064165     0.012079    0.043266   -0.037239     0.040506
# 3    0.007578     0.077164     0.008564   -0.027896   -0.017418     0.008973
# 4   -0.033303    -0.016981     0.002438   -0.038330   -0.102023    -0.034831
#
#    NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  NASDAQ.AMD  ...  NYSE.WYN  NYSE.XEC  \
# 0     0.050356    -0.035396    -0.044060   -0.014671  ... -0.049413  0.057001
# 1     0.016178     0.058286    -0.052667    0.012376  ... -0.058941  0.030277
# 2    -0.053892    -0.051099     0.030738   -0.086428  ... -0.003223  0.022125
# 3    -0.032239     0.034448     0.051511   -0.077594  ...  0.021692  0.060885
# 4    -0.011187     0.037595    -0.039683   -0.014357  ... -0.036672 -0.011451
#
#    NYSE.XEL   NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  \
# 0 -0.054623 -0.050608  0.047199 -0.057897 -0.061392 -0.062477  0.002538
# 1  0.013643 -0.040769 -0.052795  0.010238  0.031466 -0.020406 -0.081229
# 2  0.059617 -0.034587 -0.028712 -0.039074 -0.004342  0.021010 -0.066373
# 3 -0.039630  0.027694  0.012100 -0.039575  0.002900 -0.002703 -0.049420
# 4 -0.030314 -0.012030 -0.045731  0.029255 -0.003013 -0.001339 -0.003603
#
#    NYSE.ZTS
# 0 -0.051698
# 1 -0.059501
# 2  0.023570
# 3  0.015160
# 4  0.005364
#
# [5 rows x 500 columns]
